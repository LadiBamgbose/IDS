# %% [markdown]
# **Ladi Bamgbose**

# %% [markdown]
# #Project 2

# %% [markdown]
# ## Problem 1

# %% [markdown]
# **Excel:**

# %% [markdown]
# ![Screen Shot 2023-09-18 at 4.11.26 PM.png](data:image/png;base64,...)

# %% [markdown]
# The Assault column in Georgia was the only missing value and I replaced it with the average of all other assaults

# %% [markdown]
# *Murder Rate Plot*

# %% [markdown]
# ![MurderRates.png](data:image/png;base64,...)

# %% [markdown]
# *Histogram of Assaults*

# %% [markdown]
# ![AssualtHistogram.png](data:image/png;base64,...)

# %% [markdown]
# *Murder Rate vs Assault Rate*

# %% [markdown]
# ![Screen Shot 2023-09-18 at 6.10.05 PM.png](data:image/png;base64,...)

# %% [markdown]
# Here we see as Urban population increases (red) assualt rates (blue) do not neccesarily follow the linear trend.
# ![Screen Shot 2023-09-19 at 8.20.25 PM.png](data:image/png;base64,...)

# %% [markdown]
# **SQL:**

# %% [markdown]
# *Replacing all missing values with average* (update MurderRates set Assault = 170 where State = ‘Georgia’;)

# %% [markdown]
# ![updatedSQLGeorgia.png](data:image/png;base64,...)

# %% [markdown]
# *Min for the data* (select state, min(murder) from MurderRates)

# %% [markdown]
# ![minSQL.png](data:image/png;base64,...)

# %% [markdown]
# *Max for the data* (select state, max(murder) from MurderRates)

# %% [markdown]
# ![maxSQL.png](data:image/png;base64,...)

# %% [markdown]
# *Mean for the data* (select state, avg(murder) from MurderRates)

# %% [markdown]
# ![meanSQL.png](data:image/png;base64,...)

# %% [markdown]
# *Variance for the data* (select data, variance(murder) from MurderRates)

# %% [markdown]
# ![varianceSQL.png](data:image/png;base64,...)

# %% [markdown]
# As we can see, Georgia is the state with the max murder rate

# %% [markdown]
# List of states in ascending order of urban population percentages:
# Vermont
# 32
# West Virginia
# 39
# Mississippi
# 44
# North Dakota
# 44
# North Carolina
# 45
# South Dakota
# 45
# Alaska
# 48
# South Carolina
# 48
# Arkansas
# 50
# Maine
# 51
# Kentucky
# 52
# Montana
# 53
# Idaho
# 54
# New Hampshire
# 56
# Iowa
# 57
# Alabama
# 58
# Tennessee
# 59
# Georgia
# 60
# Wyoming
# 60
# Nebraska
# 62
# Virginia
# 63
# Indiana
# 65
# Kansas
# 66
# Louisiana
# 66
# Minnesota
# 66
# Wisconsin
# 66
# Maryland
# 67
# Oregon
# 67
# Oklahoma
# 68
# Missouri
# 70
# New Mexico
# 70
# Delaware
# 72
# Pennsylvania
# 72
# Washington
# 73
# Michigan
# 74
# Ohio
# 75
# Connecticut
# 77
# Colorado
# 78
# Arizona
# 80
# Florida
# 80
# Texas
# 80
# Utah
# 80
# Nevada
# 81
# Hawaii
# 83
# Illinois
# 83
# Massachusetts
# 85
# New York
# 86
# Rhode Island
# 87
# New Jersey
# 89
# California
# 91

# %% [markdown]
# 21 states have a higher murder rate than Arizona, those states are:
# Alabama
# Alaska
# Arkansas
# California
# Florida
# Georgia
# Illinois
# Kentucky
# Louisiana
# Maryland
# Michigan
# Mississippi
# Missouri
# Nevada
# New Mexico
# New York
# North Carolina
# South Carolina
# Tennessee
# Texas
# Virginia

# %% [markdown]
# ##Problem 2

# %% [markdown]
# **Excel:**

# %% [markdown]
# Filled all missing values in excel spreadsheet using the mean

# %% [markdown]
# Under-ﬁve mortality rate and neonatal mortality rate (blue is under_five, red is neonatal):

# %% [markdown]
# ![Under-ﬁve mortality rate and neonatal mortality rate.png](data:image/png;base64,...)

# %% [markdown]
# Infant mortality rate and neonatal mortality rate (blue is infant, red is neonatal):

# %% [markdown]
# ![Infant mortality rate and neonatal mortality rate.png](data:image/png;base64,...)

# %% [markdown]
# Year and infant mortality rate:

# %% [markdown]
# ![Year and infant mortality rate.png](data:image/png;base64,...)

# %% [markdown]
# **SQL**

# %% [markdown]
# Creating table:
# CREATE TABLE ChildRate
# (
#     Year INT,
#     Under_five_mortality_rate DOUBLE,
#     Infant_mortality_rate DOUBLE,
#     Neonatal_mortality_rate DOUBLE
# );
#
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('1990', 93.4, 64.8, 36.8);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('1991', 92.1, 63.9, 36.3);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('1992', 90.9, 63.1, 35.9);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('1993', 89.7, 62.3, 35.4);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('1994', 88.7, 61.4, NULL);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('1995', 87.3, 60.5, 34.4);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('1996', 85.6, 59.4, 33.7);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('1997', NULL, 58.2, 33.1);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('1998', 82.1, 56.9, 32.3);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('1999', 79.9, 55.4, 31.5);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2000', 77.5, 53.9, 30.7);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2001', 74.8, 52.1, 29.8);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2002', 72.0, NULL, 28.9);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2003', 69.2, 48.6, 28.0);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2004', 66.7, 46.9, NULL);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2005', NULL, 45.1, 26.1);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2006', 61.1, 43.4, 25.3);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2007', 58.5, NULL, 24.4);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2008', 56.2, 40.3, 23.6);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2009', 53.7, 38.8, 22.9);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2010', NULL, 37.4, 22.2);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2011', 49.3, 36.0, 21.5);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2012', 47.3, 34.7, 20.8);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2013', 45.5, 33.6, 20.2);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2014', 43.7, NULL, 19.6);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2015', 42.2, 31.4, 19.1);
# INSERT INTO ChildRate (Year, Under_five_mortality_rate, Infant_mortality_rate, Neonatal_mortality_rate) VALUES ('2016', 40.8, 30.5, 18.6);

# %% [markdown]
# The year with the lowest infant mortality rate is 2016 and the highest infant mortality rate is 1990

# %% [markdown]
# The years where the neonatal was above average are 2004
# 2003
# 2002
# 2001
# 2000
# 1999
# 1998
# 1997
# 1996
# 1995
# 1994
# 1993
# 1992
# 1991
# 1990

# %% [markdown]
# To display the sorted infant mortality rates in descending order:
# select year, infant_mortality_rate from ChildRate
# group by year
# order by infant_mortality_rate desc

# %% [markdown]
# To select the max, min, mean, standard deviation and variance:
# select max(under_five_mortality_rate) from ChildRate --
# select min(under_five_mortality_rate) from ChildRate --
# select avg(under_five_mortality_rate) from ChildRate --
# select variance(under_five_mortality_rate) from ChildRate --
# select stdev(under_five_mortality_rate) from ChildRate
# (change parameter for rest of rates)

# %% [markdown]
# Adding above_five_mortality_rate:
# alter table childrate
# add  above_five_mortality_rate DOUBLE
